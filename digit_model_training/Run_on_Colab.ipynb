# %% [markdown]
# # Train Hand Digit Model on Google Colab (from GitHub)
# Follow these steps to train your model using Colab's free GPU:
# 1. Go to **Runtime > Change runtime type** and select **T4 GPU**.
# 2. Run the cells below to clone your project directly from GitHub and start training!

# %%
# Clone the repository from GitHub
# !git clone https://github.com/adityaB-code100/hand-Digit.git
import os
os.chdir('/content/hand-Digit/digit_model_training')
# !pwd

# %%
# Install dependencies
# !pip install -r requirements.txt

# %%
# Start the training pipeline!
# !python main.py

# %% [markdown]
# ### Important Note about saving your models:
# Since Colab wipes your files when it disconnects, you can run this cell to copy the final models to your Google Drive automatically after training is done.

# %%
# Optional: Save your models back to Google Drive
from google.colab import drive
drive.mount('/content/drive')

import shutil
# !mkdir -p '/content/drive/MyDrive/Hand_Digit_Models'
shutil.copytree('/content/hand-Digit/digit_model_training/saved_models', '/content/drive/MyDrive/Hand_Digit_Models', dirs_exist_ok=True)
print("Models successfully saved to your Google Drive!")
